# %% [markdown]
# <a href="https://colab.research.google.com/github/mynameisji/ds-admission-challenge/blob/master/n311a_environment_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 3 / SPRINT 1 / NOTE 1*
#
# # 📝 Assignment
#
# # 깃헙에 패키지 만들어 올리기
#
# ### 1) 깃헙 레포 생성
#
# - 깃헙에서 레포를 생성해 봅니다.
# - 로컬과 연결해 봅니다.
# - 2개 이상의 커밋을 해봅니다.
#
# > *레포 주소를 아래에 적습니다*

# %% [markdown]
# https://github.com/mynameisji/example-day1

# %% [markdown]
# ### 2) 가상환경 설정하기
#
# - 콘다를 이용해서 파이썬 3.7 이 설치된 가상환경을 만들어 봅니다.
#
# > *`% conda info --envs` 명령어가 실행된 사진을 첨부합니다*

# %% [markdown]
# ![n311a.PNG](data:image/png;base64,...)

# %% [markdown]
# ### 3) 계산기 패키지 만들기
#
# - 더하기, 나누기, 곱하기, 빼기 등의 기능들은 포함해야 합니다.

# %%
def plus():
    a = int(input("a:"))
    b = int(input("b:"))
    result = a + b
    print(result)

def minus():
    a = int(input("a:"))
    b = int(input("b:"))
    result = a - b
    print(result)

def multi():
    a = int(input("a:"))
    b = int(input("b:"))
    result = a * b
    print(result)

# %% [markdown]
# ### 4) 🔥 도전과제
#
# - test PyPI 에 패키지를 배포해 봅니다.
#
# > *배포 주소를 아래에 적습니다*
